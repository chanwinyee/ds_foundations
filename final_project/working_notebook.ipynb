# %%
# !pip install requests
# !pip3 install requests
import requests
import json
import urllib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: requests in /anaconda3/lib/python3.6/site-packages (2.19.1)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests) (2018.4.16)
# Requirement already satisfied: requests in /anaconda3/lib/python3.6/site-packages (2.19.1)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests) (1.22)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests) (2018.4.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests) (3.0.4)

# %%
data = []
page_number = 613
signal = []

#should_request == True
#for i in range(3):

def get_bike_data():
    url = 'https://bikeindex.org:443/api/v3/search?'
    parameters = {'page:':str(page_number),
              'per_page':100,
              'location':'IP',
              'distance':25,
              'stolenness':'stolen'}
    qry = urllib.parse.urlencode(parameters).replace('%3A', '')
    s = requests.Session() #Create a Session object -  <requests.sessions.Session object at 0x1016c0198>
    req = requests.Request(method='GET', url=url) #<Request [GET]>
    prep = req.prepare() #<PreparedRequest [GET]>
    prep.url = url + qry #https://bikeindex.org:443/api/v3/search?page=2&per_page=100&location=IP&distance=25&stolenness=stolen
    result = s.send(prep) #<Response [200]>
    result.raise_for_status()

    if result.status_code == 200:
        signal.clear()
        signal.extend(result.json()['bikes'])
        #ADD TO MY DATA
        data.extend(result.json()['bikes'])

# %%
get_bike_data()

while len(signal) > 0:
    page_number = page_number + 1
    get_bike_data()
    if len(signal) == 0:
        break

# %%
bike_data = pd.DataFrame(data)

# %%
bike_data
# Out:
#       date_stolen                  frame_colors                frame_model  \
# 0    1.118988e+09                   [Blue, Red]                        220
# 1    1.118902e+09  [Silver, gray or bare metal]                 Rockhopper
# 2    1.118815e+09                       [Black]                       5000
# 3    1.118642e+09               [Green, Purple]            930 Singletrack
# 4    1.118642e+09                 [Blue, White]                        M60
# 5    1.118556e+09                 [Pink, Black]                       None
# 6    1.118470e+09                  [Black, Red]                    extreme
# 7    1.118470e+09                        [Blue]                 Cincinnati
# 8    1.118470e+09                [Green, Black]                       Euro
# 9    1.118383e+09                       [Black]                   dmc comp
# 10   1.118297e+09                        [Blue]             Solution FS AL
# 11   1.118297e+09                        [Blue]                        bmx
# 12   1.118297e+09  [Silver, gray or bare metal]                    7200 FX
# 13   1.118038e+09  [Silver, gray or bare metal]                        Jr.
# 14   1.118038e+09                        [Blue]                       HKOK
# 15   1.118038e+09                        [Blue]                       7200
# 16   1.117951e+09        [Yellow or Gold, Blue]                       3900
# 17   1.117865e+09  [Silver, gray or bare metal]                 Boulder SE
# 18   1.117865e+09                        [Blue]                     sparta
# 19   1.117865e+09                   [Blue, Red]                  mr. lucky
# 20   1.117692e+09  [Yellow or Gold, Red, Black]                    sugar 1
# 21   1.117692e+09  [Silver, gray or bare metal]                        440
# 22   1.117606e+09                         [Red]                 Jekyll 800
# 23   1.117606e+09              [Yellow or Gold]                       NuNu
# 24   1.117606e+09                       [Black]                     Sirrus
# 25   1.117606e+09                      [Orange]                      yukon
# 26   1.117606e+09  [Silver, gray or bare metal]                 proline 24
# 27   1.117606e+09                        [Blue]          Pocket Rocket Pro
# 28   1.117519e+09                       [Green]                      Wahoo
# 29   1.117260e+09  [Silver, gray or bare metal]         Ruckus I drive 1.0
# ..            ...                           ...                        ...
# 353  8.841528e+08                         [Red]                       None
# 354  8.841528e+08                         [Red]                        925
# 355  8.840664e+08                       [Black]                    brugham
# 356  8.840664e+08                       [Green]                  BMX style
# 357  8.838936e+08  [Silver, gray or bare metal]                    Quick 5
# 358  8.838936e+08  [Silver, gray or bare metal]                     Sub 20
# 359  8.838072e+08                       [Black]                   Escape 2
# 360  8.836344e+08                       [Green]              Beach Cruiser
# 361  8.836344e+08              [Yellow or Gold]                 Flight 100
# 362  8.836344e+08                       [Black]                      Turbo
# 363  8.747352e+08        [Blue, Yellow or Gold]                   Tequesta
# 364  8.449704e+08                         [Red]                 S-Works M2
# 365  8.442216e+08                       [Black]                  00-93-276
# 366  7.763256e+08                         [Red]                   Pinnacle
# 367  7.742520e+08                         [Red]                    Vertigo
# 368  7.739928e+08                      [Purple]                      NYALA
# 369  6.391224e+08                         [Red]                     LeMans
# 370  5.213592e+08  [Silver, gray or bare metal]                     Styler
# 371  4.944024e+08                        [Blue]                122 Varsity
# 372  3.000888e+08              [Yellow or Gold]  Continental Mens 10 speed
# 373  7.302960e+07                  [Black, Red]                       YR2C
# 374  5.661360e+07  [Silver, gray or bare metal]                  Paramount
# 375  1.527711e+09                       [Black]                 CrossTrail
# 376           NaN               [Orange, White]                    2.1 WSD
# 377           NaN              [Yellow or Gold]             2700 GT Deluxe
# 378           NaN                       [White]                       XO-1
# 379           NaN                        [Blue]                    Roubaix
# 380           NaN                        [Blue]                   Commuter
# 381           NaN  [Silver, gray or bare metal]                   TRANCE 2
# 382           NaN                       [White]                       QX75
#
#          id  is_stock_img                                          large_img  \
# 0      4156         False                                               None
# 1      4158         False                                               None
# 2      3955          True  https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 3      4162         False                                               None
# 4      4780         False                                               None
# 5      4236         False                                               None
# 6      4149         False                                               None
# 7      4148         False                                               None
# 8      4154         False                                               None
# 9      4027         False                                               None
# 10     3933         False                                               None
# 11     4145         False                                               None
# 12     4731          True  https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 13     4151         False                                               None
# 14     4150         False                                               None
# 15     4961         False                                               None
# 16     4142          True  https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 17     4143         False                                               None
# 18     3952         False                                               None
# 19     4173         False                                               None
# 20     4138         False                                               None
# 21     4139         False                                               None
# 22     3935         False                                               None
# 23     4164         False                                               None
# 24     3936          True  https://bikebook.s3.amazonaws.com/uploads/Fr/5...
# 25     4737         False                                               None
# 26     3954         False                                               None
# 27     4105         False                                               None
# 28     4140          True  https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 29     4135         False                                               None
# ..      ...           ...                                                ...
# 353   24554         False                                               None
# 354   15894         False                                               None
# 355   15891         False                                               None
# 356   15889         False                                               None
# 357   23999         False  https://files.bikeindex.org/uploads/Pu/8375/la...
# 358   15880         False                                               None
# 359   21605         False                                               None
# 360    9541         False                                               None
# 361   16692         False                                               None
# 362    9327         False                                               None
# 363   63641         False  https://files.bikeindex.org/uploads/Pu/40960/l...
# 364  407158         False                                               None
# 365  434380         False                                               None
# 366   42608         False                                               None
# 367    6388         False                                               None
# 368   38234         False                                               None
# 369  111106         False                                               None
# 370   33570         False                                               None
# 371   29382         False                                               None
# 372  111269         False                                               None
# 373  353155         False                                               None
# 374   34632         False                                               None
# 375  395098         False  https://files.bikeindex.org/uploads/Pu/119807/...
# 376   17245          True  https://bikebook.s3.amazonaws.com/uploads/Fr/1...
# 377   34345         False  https://files.bikeindex.org/uploads/Pu/15988/l...
# 378   77217         False  https://files.bikeindex.org/uploads/Pu/53893/l...
# 379   79043         False  https://files.bikeindex.org/uploads/Pu/55393/l...
# 380   70745         False  https://files.bikeindex.org/uploads/Pu/47978/l...
# 381   75114         False  https://files.bikeindex.org/uploads/Pu/52645/l...
# 382   43810         False  https://files.bikeindex.org/uploads/Pu/23428/l...
#
#     manufacturer_name           serial  stolen  \
# 0                Trek          CC85883    True
# 1         Specialized         PQ849467    True
# 2                Trek        WL3271480    True
# 3                Trek          1479417    True
# 4             Raleigh        U19K23185    True
# 5                Next           absent    True
# 6                 Amx           absent    True
# 7            DK Bikes        u46u26946    True
# 8               Solid           absent    True
# 9                  K2       7143484123    True
# 10            Schwinn        HN0302908    True
# 11           Mongoose           absent    True
# 12               Trek         C840C658    True
# 13            Redline           absent    True
# 14        Gary Fisher         C84GP356    True
# 15               Trek       ITK2G27166    True
# 16               Trek         CB4HK098    True
# 17              Giant         GJ4M3163    True
# 18            Bianchi        200405406    True
# 19        Diamondback       af01i00253    True
# 20        Gary Fisher           absent    True
# 21            Redline             8473    True
# 22         Cannondale          N068470    True
# 23               Kona         H1K56528    True
# 24        Specialized        P5A534829    True
# 25              Giant         ge1b0802    True
# 26            Redline  554114111477pfd    True
# 27        Bike Friday            11224    True
# 28        Gary Fisher         C72FL901    True
# 29        GT Bicycles     AS 2080 2015    True
# ..                ...              ...     ...
# 353          Ez Rider           absent    True
# 354           Redline        HR1123250    True
# 355              Felt           absent    True
# 356           Unknown           absent    True
# 357        Cannondale          XM48507    True
# 358             SCOTT         gm676100    True
# 359             Giant         C21A0096    True
# 360           Del Sol           absent    True
# 361      KHS Bicycles           absent    True
# 362       Diamondback           2F0099    True
# 363       GT Bicycles         SY5L0965    True
# 364       Specialized           absent    True
# 365             Giant         G03L1223    True
# 366       Klein Bikes           R3638D    True
# 367       GT Bicycles         G9121411    True
# 368           Bianchi         H9N21382    True
# 369         Centurion          n8e8265    True
# 370               MCS              198    True
# 371           Schwinn         MM555764    True
# 372           Schwinn           absent    True
# 373            Yamaha         R2053468    True
# 374           Schwinn            H7008    True
# 375       Specialized           absent    True
# 376              Trek     WTU241G0902D    True
# 377             Sekai           absent    True
# 378       Bridgestone          X125870    True
# 379              Fuji     WBD005L0614K    True
# 380       Coon Cycles             none    True
# 381             Giant         GN602448    True
# 382              Felt       AJ30003323    True
#
#                        stolen_location  \
# 0                  Germantown,MD,20874
# 1                   Lafayette,CA,94549
# 2                     Seattle,WA,98115
# 3                      Tucson,AZ,85721
# 4                     Ardmore,PA,19003
# 5                    Danville,IL,61832
# 6                      Severn,MD,21144
# 7               Maple Heights,OH,44137
# 8                    Richmond,CA,94804
# 9                      Tucson,AZ,85711
# 10                    Chicago,IL,60607
# 11                   Voorhees,NJ,08043
# 12                     Boston,MA,02199
# 13                   Chicopee,MA,01020
# 14                    Buffalo,NY,14201
# 15                   Portland,OR,97215
# 16                     Austin,TX,78751
# 17                  San Diego,CA,92109
# 18                Minneapolis,MN,55421
# 19                     Tucson,AZ,85741
# 20                    Concord,CA,94519
# 21                  Vancouver,WA,98665
# 22                       Orem,UT,84057
# 23                       Toronto,00000
# 24                     Tucson,AZ,85721
# 25                       Ames,IA,50014
# 26                     Boston,MA,02114
# 27                San Antonio,TX,78212
# 28                 Northfield,MN,55057
# 29                    Seattle,WA,98105
# ..                                 ...
# 353               Old Hickory,TN,37138
# 354                  Portland,OR,97215
# 355                  Portland,OR,97212
# 356            New Alexandria,PA,15670
# 357                    Eugene,OR,97401
# 358                 Corvallis,OR,97333
# 359             San Francisco,CA,94117
# 360               Miami Beach,FL,33140
# 361                  Portland,OR,97203
# 362                     Miami,FL,33173
# 363                      Ames,IA,50011
# 364                   Red Deer,t4n 5h5
# 365                   Buffalo,NY,14215
# 366                       Boston,02215
# 367                 Indianapolis,46268
# 368                  Minneapolis,55418
# 369                   San Francisco,CA
# 370                   Phoenix,AZ,85032
# 371                 Champaign,IL,61820
# 372                         Raleigh,NC
# 373                         Phoenix,AZ
# 374  F & M College Campus,PA,Lancaster
# 375
# 376                               None
# 377                               None
# 378                               None
# 379                               None
# 380                               None
# 381                               None
# 382                               None
#
#                                                  thumb  \
# 0                                                 None
# 1                                                 None
# 2    https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11                                                None
# 12   https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 13                                                None
# 14                                                None
# 15                                                None
# 16   https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 17                                                None
# 18                                                None
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23                                                None
# 24   https://bikebook.s3.amazonaws.com/uploads/Fr/5...
# 25                                                None
# 26                                                None
# 27                                                None
# 28   https://bikebook.s3.amazonaws.com/uploads/Fr/2...
# 29                                                None
# ..                                                 ...
# 353                                               None
# 354                                               None
# 355                                               None
# 356                                               None
# 357  https://files.bikeindex.org/uploads/Pu/8375/sm...
# 358                                               None
# 359                                               None
# 360                                               None
# 361                                               None
# 362                                               None
# 363  https://files.bikeindex.org/uploads/Pu/40960/s...
# 364                                               None
# 365                                               None
# 366                                               None
# 367                                               None
# 368                                               None
# 369                                               None
# 370                                               None
# 371                                               None
# 372                                               None
# 373                                               None
# 374                                               None
# 375  https://files.bikeindex.org/uploads/Pu/119807/...
# 376  https://bikebook.s3.amazonaws.com/uploads/Fr/1...
# 377  https://files.bikeindex.org/uploads/Pu/15988/s...
# 378  https://files.bikeindex.org/uploads/Pu/53893/s...
# 379  https://files.bikeindex.org/uploads/Pu/55393/s...
# 380  https://files.bikeindex.org/uploads/Pu/47978/s...
# 381  https://files.bikeindex.org/uploads/Pu/52645/s...
# 382  https://files.bikeindex.org/uploads/Pu/23428/s...
#
#                                       title    year
# 0                             1999 Trek 220  1999.0
# 1               1999 Specialized Rockhopper  1999.0
# 2                            2005 Trek 5000  2005.0
# 3                 1995 Trek 930 Singletrack  1995.0
# 4                          2004 Raleigh M60  2004.0
# 5                                      Next     NaN
# 6                               Amx extreme     NaN
# 7                  2005 DK Bikes Cincinnati  2005.0
# 8                           2004 Solid Euro  2004.0
# 9                          2005 K2 dmc comp  2005.0
# 10              2003 Schwinn Solution FS AL  2003.0
# 11                        2005 Mongoose bmx  2005.0
# 12                        2005 Trek 7200 FX  2005.0
# 13                         2003 Redline Jr.  2003.0
# 14                    2005 Gary Fisher HKOK  2005.0
# 15                                Trek 7200     NaN
# 16                           2005 Trek 3900  2005.0
# 17                    2005 Giant Boulder SE  2005.0
# 18                         5 Bianchi sparta     5.0
# 19                    Diamondback mr. lucky     NaN
# 20                 2000 Gary Fisher sugar 1  2000.0
# 21                         1987 Redline 440  1987.0
# 22               2003 Cannondale Jekyll 800  2003.0
# 23                           2002 Kona NuNu  2002.0
# 24                  2005 Specialized Sirrus  2005.0
# 25                         2002 Giant yukon  2002.0
# 26                  2004 Redline proline 24  2004.0
# 27       2003 Bike Friday Pocket Rocket Pro  2003.0
# 28                   2004 Gary Fisher Wahoo  2004.0
# 29      2003 GT Bicycles Ruckus I drive 1.0  2003.0
# ..                                      ...     ...
# 353                                Ez Rider     NaN
# 354                        2007 Redline 925  2007.0
# 355                            Felt brugham     NaN
# 356                  2010 Unknown BMX style  2010.0
# 357                      Cannondale Quick 5     NaN
# 358                       2008 SCOTT Sub 20  2008.0
# 359                     2010 Giant Escape 2  2010.0
# 360                   Del Sol Beach Cruiser     NaN
# 361            2006 KHS Bicycles Flight 100  2006.0
# 362                  1982 Diamondback Turbo  1982.0
# 363               1995 GT Bicycles Tequesta  1995.0
# 364             1994 Specialized S-Works M2  1994.0
# 365                    1993 Giant 00-93-276  1993.0
# 366               1991 Klein Bikes Pinnacle  1991.0
# 367                1991 GT Bicycles Vertigo  1991.0
# 368                      1990 Bianchi NYALA  1990.0
# 369                   1980 Centurion LeMans  1980.0
# 370                         1985 MCS Styler  1985.0
# 371                1976 Schwinn 122 Varsity  1976.0
# 372  1972 Schwinn Continental Mens 10 speed  1972.0
# 373                        1968 Yamaha YR2C  1968.0
# 374                  1970 Schwinn Paramount  1970.0
# 375             2010 Specialized CrossTrail  2010.0
# 376                       2009 Trek 2.1 WSD  2009.0
# 377               1979 Sekai 2700 GT Deluxe  1979.0
# 378                   1992 Bridgestone XO-1  1992.0
# 379                       2015 Fuji Roubaix  2015.0
# 380               2012 Coon Cycles Commuter  2012.0
# 381                     2016 Giant TRANCE 2  2016.0
# 382                               Felt QX75     NaN
#
# [383 rows x 13 columns]
